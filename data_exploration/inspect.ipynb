# %%
import pandas as pd 
from graph_builder.config.Config import Config
from pathlib import Path
import pandas_gbq
import db_dtypes

# %%
df_dir = Config.output_folder
df_diag = pd.read_parquet(Path(df_dir) / 'diagnosis.parquet')
df_admissions = pd.read_parquet(Path(df_dir) / 'admissions.parquet')
df_patients = pd.read_parquet(Path(df_dir) / 'patients.parquet')

# %%
df_admissions.duplicated().any()
df_patients.duplicated().any()
df_diag.duplicated().any()
# Out:
# False

# %%
df_patients['subject_id'].is_unique
# Out:
# 0         10078138
# 1         10180372
# 2         10686175
# 3         10851602
# 4         10902424
#             ...
# 299707    11965764
# 299708    14476240
# 299709    17217407
# 299710    18539655
# 299711    15211528
# Name: subject_id, Length: 299712, dtype: Int64

# %%
df_admissions
# Out:
#         subject_id   hadm_id           admittime           dischtime
# 0         10106244  26713233 2147-05-09 10:34:00 2147-05-12 13:43:00  \
# 1         13700703  20448599 2172-09-25 01:01:00 2172-10-03 13:25:00
# 2         15443666  27961368 2168-12-30 23:30:00 2169-01-05 16:02:00
# 3         16299919  26977065 2193-05-15 08:37:00 2193-05-17 16:03:00
# 4         19596808  26675460 2128-06-04 16:13:00 2128-06-05 11:36:00
# ...            ...       ...                 ...                 ...
# 431226    19772551  28019655 2186-07-25 16:56:00 2186-07-26 15:00:00
# 431227    19791178  23858200 2115-04-26 12:57:00 2115-04-27 16:45:00
# 431228    19956654  22281279 2137-06-26 13:07:00 2137-06-27 12:15:00
# 431229    17164360  27226215 2143-12-15 07:15:00 2143-12-17 15:14:00
# 431230    12104929  28540937 2162-07-12 22:48:00 2162-07-17 16:10:00
#
#        deathtime               admission_type admit_provider_id
# 0            NaT                 DIRECT EMER.              None  \
# 1            NaT            OBSERVATION ADMIT              None
# 2            NaT            OBSERVATION ADMIT              None
# 3            NaT            OBSERVATION ADMIT              None
# 4            NaT                     EW EMER.            P0038O
# ...          ...                          ...               ...
# 431226       NaT       AMBULATORY OBSERVATION            P99YFT
# 431227       NaT       AMBULATORY OBSERVATION            P99YFT
# 431228       NaT       AMBULATORY OBSERVATION            P99YFT
# 431229       NaT  SURGICAL SAME DAY ADMISSION            P99YFT
# 431230       NaT                     EW EMER.            P99YTS
#
#         admission_location discharge_location insurance language
# 0       PHYSICIAN REFERRAL               HOME     Other  ENGLISH  \
# 1           EMERGENCY ROOM               HOME     Other  ENGLISH
# 2           EMERGENCY ROOM   HOME HEALTH CARE     Other  ENGLISH
# 3           EMERGENCY ROOM            HOSPICE  Medicare  ENGLISH
# 4           EMERGENCY ROOM               HOME  Medicare  ENGLISH
# ...                    ...                ...       ...      ...
# 431226      PROCEDURE SITE               None  Medicare  ENGLISH
# 431227      PROCEDURE SITE               None     Other        ?
# 431228      PROCEDURE SITE               None  Medicare  ENGLISH
# 431229  PHYSICIAN REFERRAL               HOME     Other  ENGLISH
# 431230      EMERGENCY ROOM   HOME HEALTH CARE  Medicare  ENGLISH
#
#        marital_status                         race           edregtime
# 0              SINGLE                        WHITE                 NaT  \
# 1             MARRIED                        WHITE 2172-09-24 17:38:00
# 2              SINGLE       BLACK/AFRICAN AMERICAN 2168-12-30 11:19:00
# 3             WIDOWED       BLACK/AFRICAN AMERICAN 2193-05-15 04:36:00
# 4             MARRIED                        WHITE 2128-06-04 13:25:00
# ...               ...                          ...                 ...
# 431226         SINGLE                        OTHER                 NaT
# 431227         SINGLE  HISPANIC/LATINO - DOMINICAN                 NaT
# 431228        MARRIED                        WHITE                 NaT
# 431229         SINGLE   PATIENT DECLINED TO ANSWER 2143-12-15 09:40:00
# 431230        WIDOWED                        WHITE 2162-07-12 11:39:00
#
#                  edouttime  hospital_expire_flag
# 0                      NaT                     0
# 1      2172-09-25 03:07:00                     0
# 2      2168-12-31 01:22:00                     0
# 3      2193-05-15 14:27:00                     0
# 4      2128-06-04 16:59:00                     0
# ...                    ...                   ...
# 431226                 NaT                     0
# 431227                 NaT                     0
# 431228                 NaT                     0
# 431229 2143-12-15 14:47:00                     0
# 431230 2162-07-13 00:22:00                     0
#
# [431231 rows x 16 columns]
